# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusFUU/analise-quilombolas/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c65bb0d5-1a40-4fbf-92fe-f0d70058322c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c65bb0d5-1a40-4fbf-92fe-f0d70058322c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
populacao_quilombolas = next(iter(uploaded))

# %%
df = pd.read_excel(populacao_quilombolas)

# %%
df
# Out:
#                Unidade da Federação Pessoas quilombolas (Pessoas)  \
# 0                            Brasil                       1327802
# 1                          Rondônia                          2926
# 2                              Acre                             -
# 3                          Amazonas                          2705
# 4                           Roraima                             -
# 5                              Pará                        135033
# 6                             Amapá                         12524
# 7                         Tocantins                         12881
# 8                          Maranhão                        269074
# 9                             Piauí                         31686
# 10                            Ceará                         23955
# 11              Rio Grande do Norte                         22384
# 12                          Paraíba                         16584
# ...

# %%
df[[df.columns[0], df.columns[1]]]
# Out:
#                Unidade da Federação Pessoas quilombolas (Pessoas)
# 0                            Brasil                       1327802
# 1                          Rondônia                          2926
# 2                              Acre                             -
# 3                          Amazonas                          2705
# 4                           Roraima                             -
# 5                              Pará                        135033
# 6                             Amapá                         12524
# 7                         Tocantins                         12881
# 8                          Maranhão                        269074
# 9                             Piauí                         31686
# 10                            Ceará                         23955
# 11              Rio Grande do Norte                         22384
# 12                          Paraíba                         16584
# ...

# %%
df[[df.columns[0], df.columns[2]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...

# %%
df[[df.columns[0], df.columns[3]]]
# Out:
#                Unidade da Federação  População residente (Pessoas)
# 0                            Brasil                    203062512.0
# 1                          Rondônia                      1581016.0
# 2                              Acre                       830026.0
# 3                          Amazonas                      3941175.0
# 4                           Roraima                       636303.0
# 5                              Pará                      8116132.0
# 6                             Amapá                       733508.0
# 7                         Tocantins                      1511459.0
# 8                          Maranhão                      6775152.0
# 9                             Piauí                      3269200.0
# 10                            Ceará                      8791688.0
# 11              Rio Grande do Norte                      3302406.0
# 12                          Paraíba                      3974495.0
# ...

# %%
df[[df.columns[0], df.columns[4]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...

# %%
df[[df.columns[0], df.columns[5]]]
# Out:
#                Unidade da Federação Pessoas quilombolas (Pessoas).1
# 0                            Brasil                          167202
# 1                          Rondônia                             221
# 2                              Acre                               -
# 3                          Amazonas                            1229
# 4                           Roraima                               -
# 5                              Pará                           44533
# 6                             Amapá                            4701
# 7                         Tocantins                            1328
# 8                          Maranhão                           29044
# 9                             Piauí                            8411
# 10                            Ceará                            4595
# 11              Rio Grande do Norte                            3445
# 12                          Paraíba                            2918
# ...

# %%
df[[df.columns[0], df.columns[6]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...

# %%
df[[df.columns[0], df.columns[7]]]
# Out:
#                Unidade da Federação População residente (Pessoas).1
# 0                            Brasil                          203518
# 1                          Rondônia                             231
# 2                              Acre                               -
# 3                          Amazonas                            1418
# 4                           Roraima                               -
# 5                              Pará                           48626
# 6                             Amapá                            6788
# 7                         Tocantins                            1903
# 8                          Maranhão                           33351
# 9                             Piauí                            8716
# 10                            Ceará                            7879
# 11              Rio Grande do Norte                            3633
# 12                          Paraíba                            6026
# ...

# %%
df[[df.columns[0], df.columns[8]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...

# %%
df[[df.columns[0], df.columns[9]]]
# Out:
#                Unidade da Federação Pessoas quilombolas (Pessoas).2
# 0                            Brasil                         1160600
# 1                          Rondônia                            2705
# 2                              Acre                               -
# 3                          Amazonas                            1476
# 4                           Roraima                               -
# 5                              Pará                           90500
# 6                             Amapá                            7823
# 7                         Tocantins                           11553
# 8                          Maranhão                          240030
# 9                             Piauí                           23275
# 10                            Ceará                           19360
# 11              Rio Grande do Norte                           18939
# 12                          Paraíba                           13666
# ...

# %%
df[[df.columns[0], df.columns[10]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...

# %%
df[[df.columns[0], df.columns[11]]]
# Out:
#                Unidade da Federação  População residente (Pessoas).2
# 0                            Brasil                      202858994.0
# 1                          Rondônia                        1580785.0
# 2                              Acre                         830026.0
# 3                          Amazonas                        3939757.0
# 4                           Roraima                         636303.0
# 5                              Pará                        8067506.0
# 6                             Amapá                         726720.0
# 7                         Tocantins                        1509556.0
# 8                          Maranhão                        6741801.0
# 9                             Piauí                        3260484.0
# 10                            Ceará                        8783809.0
# 11              Rio Grande do Norte                        3298773.0
# 12                          Paraíba                        3968469.0
# ...

# %%
df[[df.columns[0], df.columns[12]]]
# Out:
#                Unidade da Federação  \
# 0                            Brasil
# 1                          Rondônia
# 2                              Acre
# 3                          Amazonas
# 4                           Roraima
# 5                              Pará
# 6                             Amapá
# 7                         Tocantins
# 8                          Maranhão
# 9                             Piauí
# 10                            Ceará
# 11              Rio Grande do Norte
# 12                          Paraíba
# 13                       Pernambuco
# 14                          Alagoas
# 15                          Sergipe
# 16                            Bahia
# 17                     Minas Gerais
# 18                   Espírito Santo
# 19                   Rio de Janeiro
# 20                        São Paulo
# 21                           Paraná
# 22                   Santa Catarina
# 23                Rio Grande do Sul
# 24               Mato Grosso do Sul
# ...
